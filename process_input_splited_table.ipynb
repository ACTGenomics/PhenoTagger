# %%
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize

# 下載NLTK模型
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

def text_to_sentence_pubtator(df, id_col='index', text_col='clinical_summary'):
    """
    將文本按句子拆分轉換為PubTator格式
    每個句子一個條目，使用原始ID
    """
    lines = []
    for _, row in df.iterrows():
        original_id = str(row[id_col])
        text = str(row[text_col])
        
        # 句子切割
        sentences = sent_tokenize(text)
        for sentence in sentences:
            sentence = sentence.strip()
            if sentence:
                lines.append(f"{original_id}|t|{sentence}")
                lines.append(f"{original_id}|a|{sentence}")
                lines.append("")  # 空行
    
    return "\n".join(lines)

def save_pubtator_format(df: pd.DataFrame, output_file: str = "output_pubtator.txt"):
    """
    將DataFrame轉換為PubTator格式並儲存到檔案
    
    Parameters:
    df (pd.DataFrame): 包含case_id和clinical_summary欄位的DataFrame
    output_file (str): 輸出檔案名稱
    """
    pubtator_text = text_to_sentence_pubtator(df)
    
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(pubtator_text)
    
    print(f"PubTator格式文件已儲存至: {output_file}")
    return pubtator_text

def read_pubtator_file(file_path):
    """
    從檔案讀取PubTator格式文本
    """
    with open(file_path, 'r', encoding='utf-8') as f:
        return f.read()

def merge_hpo_by_id(pubtator_text):
    """
    讀取PubTator，將相同ID的HPO註釋合併
    """
    lines = pubtator_text.strip().split('\n')
    data = {}
    
    for line in lines:
        line = line.strip()
        if not line:
            continue
            
        # 解析註釋行
        if '\t' in line and len(line.split('\t')) >= 6:
            parts = line.split('\t')
            id_val = parts[0]
            text = parts[3]
            entity_type = parts[4]
            hpo_id = parts[5]
            
            if entity_type == 'Phenotype' and hpo_id.startswith('HP:'):
                if id_val not in data:
                    data[id_val] = {'hpo_terms': [], 'hpo_ids': []}
                
                if text not in data[id_val]['hpo_terms']:
                    data[id_val]['hpo_terms'].append(f"{text} ({hpo_id})")
                if hpo_id not in data[id_val]['hpo_ids']:
                    data[id_val]['hpo_ids'].append(hpo_id)
    
    # 轉換為DataFrame
    result = []
    for id_val, info in data.items():
        result.append({
            'index': id_val,
            'hpo_terms': ';'.join(info['hpo_terms']),
            'hpo_ids': ','.join(info['hpo_ids'])
        })
    
    return pd.DataFrame(result)


def read_and_merge_pubtator(file_path):
    """
    讀取PubTator檔案並合併相同ID的HPO註釋
    """
    pubtator_text = read_pubtator_file(file_path)
    return merge_hpo_by_id(pubtator_text)

# # 使用範例
# if __name__ == "__main__":
#     # 範例1: 文本轉句子PubTator
#     df = pd.DataFrame({
#         'case_id': ['case1', 'case2'],
#         'clinical_summary': [
#             'Patient has fever. Also shows rash.',
#             'Cardiac defect noted. Growth delay observed.'
#         ]
#     })
    
#     pubtator = text_to_sentence_pubtator(df)
#     print("=== 句子PubTator格式 ===")
#     print(pubtator)
    
#     # 範例2: 模擬HPO註釋後的PubTator
#     annotated_pubtator = """case1|t|Patient has fever.
# case1|a|Patient has fever.
# case1	0	5	fever	Phenotype	HP:0001945	0.99

# case1|t|Also shows rash.
# case1|a|Also shows rash.
# case1	11	15	rash	Phenotype	HP:0000988	0.95

# case2|t|Cardiac defect noted.
# case2|a|Cardiac defect noted.
# case2	0	14	Cardiac defect	Phenotype	HP:0001627	0.98"""
    
    # 範例3: 讀取檔案並合併HPO
    # merged_df = read_and_merge_pubtator('annotated_output.txt')
    # print("\n=== 從檔案讀取並合併 ===")
    # print(merged_df)

# %%
biolarkgsc_copd_phenochf = pd.read_excel('../PhenoBERT/reference/biolarkgsc_copd_phenochf.xlsx',engine='openpyxl')
biolarkgsc_copd_phenochf['index'] = list(range(0, biolarkgsc_copd_phenochf.shape[0]))
biolarkgsc_copd_phenochf.to_excel('../PhenoBERT/reference/biolarkgsc_copd_phenochf.xlsx',index=False)
save_pubtator_format(biolarkgsc_copd_phenochf[biolarkgsc_copd_phenochf.dataset=='biolarkgsc'], './input/biolarkgsc.PubTator')
#save_pubtator_format(biolarkgsc_copd_phenochf, './input/biolarkgsc_copd_phenochf_splited.PubTator')
# Out:
# PubTator格式文件已儲存至: ./input/biolarkgsc.PubTator
# '0|t|A syndrome of brachydactyly (absence of some middle or distal phalanges), aplastic or hypoplastic nails, symphalangism (ankylois of proximal interphalangeal joints), synostosis of some carpal and tarsal bones, craniosynostosis, and dysplastic hip joints is reported in five members of an Italian family.\n0|a|A syndrome of brachydactyly (absence of some middle or distal phalanges), aplastic or hypoplastic nails, symphalangism (ankylois of proximal interphalangeal joints), synostosis of some carpal and tarsal bones, craniosynostosis, and dysplastic hip joints is reported in five members of an Italian family.\n\n0|t|It may represent a previously undescribed autosomal dominant trait.\n0|a|It may represent a previously undescribed autosomal dominant trait.\n\n1|t|Townes-Brocks syndrome (TBS) is an autosomal dominant disorder with multiple malformations and variable expression.\n1|a|Townes-Brocks syndrome (TBS) is an autosomal dominant disorder with multiple malformations and variable expression.\n\n1|t|Major findings include external ear anomalies, hearing loss, preaxial polydactyly and triphalangeal thumbs, imperforate anus, and renal malformations.\n1|a|Major findings include external ear anomalies, hearing loss, preaxial polydactyly and triphalangeal thumbs, imperforate anus, and renal malformations.\n\n1|t|Most patients with Townes-Brocks syndrome have normal intelligence, although mental retardation has been noted in a few.\n1|a|Most patients with Townes-Brocks syndrome have normal intelligence, although mental retardation has been noted in a few.\n\n2|t|Nevoid basal cell carcinoma syndrome (NBCCS) is a hereditary condition transmitted as an autosomal dominant trait with complete penetrance and variable expressivity.\n2|a|Nevoid basal cell carcinoma syndrome (NBCCS) is a hereditary condition transmitted as an autosomal dominant trait with complete penetrance and variable expressivity.\n\n2|t|The syndrome is characterised by numerous basal cell carcinomas (BCCs), odontogenic keratocysts of the jaws, palmar and/or plantar pits, skeletal abnormalities and intracranial calcifications.\n2|a|The syndrome is characterised by numerous basal cell carcinomas (BCCs), odontogenic keratocysts of the jaws, palmar and/or plantar pits, skeletal abnormalities and intracranial calcifications.\n\n2|t|In this paper, the clinical features of 37 Italian patients are reviewed.\n2|a|In this paper, the clinical features of 37 Italian patients are reviewed.\n\n2|t|Jaw cysts and calcification of falx cerebri were the most frequently observed anomalies, followed by BCCs and palmar/plantar pits.\n2|a|Jaw cysts and calcification of falx cerebri were the most frequently observed anomalies, followed by BCCs and palmar/plantar pits.\n\n2|t|Similar to the case of African Americans, the relatively low frequency of BCCs in the Italian population is probably due to protective skin pigmentation.\n2|a|Similar to the case of African Americans, the relatively low frequency of BCCs in the Italian population is probably due to protective skin pigmentation.\n\n2|t|A future search based on mutation screening might establish a possible genotype phenotype correlation in Italian patients.\n2|a|A future search based on mutation screening might establish a possible genotype phenotype correlation in Italian patients.\n\n3|t|Angelman syndrome (AS) is a neurodevelopmental disorder caused by the absence of a maternal contribution to chromosome 15q11-q13.\n3|a|Angelman syndrome (AS) is a neurodevelopmental disorder caused by the absence of a maternal contribution to chromosome 15q11-q13.\n\n3|t|There are four classes of AS according to molecular or cytogenetic status: maternal microdeletion of 15q11-q13 (approximately 70% of AS patients); uniparental disomy (UPD); defects in a putative imprinting centre (IM); the fourth includes 20-30% of AS individuals with biparental inheritance and a normal pattern of allelic methylation in 15q11-q13.\n3|a|There are four classes of AS accor ...

# %%
len(biolarkgsc_copd_phenochf.id.unique())
# Out:
# 2138

# %%
biolarkgsc_copd_phenochf.shape[0]
# Out:
# 2138

# %%
# save_pubtator_format(biolarkgsc_copd_phenochf[biolarkgsc_copd_phenochf.dataset=='biolarkgsc'], './input/biolarkgsc.PubTator')
# Out:
# PubTator格式文件已儲存至: ./input/biolarkgsc.PubTator
# '1003450|t|A syndrome of brachydactyly (absence of some middle or distal phalanges), aplastic or hypoplastic nails, symphalangism (ankylois of proximal interphalangeal joints), synostosis of some carpal and tarsal bones, craniosynostosis, and dysplastic hip joints is reported in five members of an Italian family.\n1003450|a|A syndrome of brachydactyly (absence of some middle or distal phalanges), aplastic or hypoplastic nails, symphalangism (ankylois of proximal interphalangeal joints), synostosis of some carpal and tarsal bones, craniosynostosis, and dysplastic hip joints is reported in five members of an Italian family.\n\n1003450|t|It may represent a previously undescribed autosomal dominant trait.\n1003450|a|It may represent a previously undescribed autosomal dominant trait.\n\n10051003|t|Townes-Brocks syndrome (TBS) is an autosomal dominant disorder with multiple malformations and variable expression.\n10051003|a|Townes-Brocks syndrome (TBS) is an autosomal dominant disorder with multiple malformations and variable expression.\n\n10051003|t|Major findings include external ear anomalies, hearing loss, preaxial polydactyly and triphalangeal thumbs, imperforate anus, and renal malformations.\n10051003|a|Major findings include external ear anomalies, hearing loss, preaxial polydactyly and triphalangeal thumbs, imperforate anus, and renal malformations.\n\n10051003|t|Most patients with Townes-Brocks syndrome have normal intelligence, although mental retardation has been noted in a few.\n10051003|a|Most patients with Townes-Brocks syndrome have normal intelligence, although mental retardation has been noted in a few.\n\n10066029|t|Nevoid basal cell carcinoma syndrome (NBCCS) is a hereditary condition transmitted as an autosomal dominant trait with complete penetrance and variable expressivity.\n10066029|a|Nevoid basal cell carcinoma syndrome (NBCCS) is a hereditary condition transmitted as an autosomal dominant trait with complete penetrance and variable expressivity.\n\n10066029|t|The syndrome is characterised by numerous basal cell carcinomas (BCCs), odontogenic keratocysts of the jaws, palmar and/or plantar pits, skeletal abnormalities and intracranial calcifications.\n10066029|a|The syndrome is characterised by numerous basal cell carcinomas (BCCs), odontogenic keratocysts of the jaws, palmar and/or plantar pits, skeletal abnormalities and intracranial calcifications.\n\n10066029|t|In this paper, the clinical features of 37 Italian patients are reviewed.\n10066029|a|In this paper, the clinical features of 37 Italian patients are reviewed.\n\n10066029|t|Jaw cysts and calcification of falx cerebri were the most frequently observed anomalies, followed by BCCs and palmar/plantar pits.\n10066029|a|Jaw cysts and calcification of falx cerebri were the most frequently observed anomalies, followed by BCCs and palmar/plantar pits.\n\n10066029|t|Similar to the case of African Americans, the relatively low frequency of BCCs in the Italian population is probably due to protective skin pigmentation.\n10066029|a|Similar to the case of African Americans, the relatively low frequency of BCCs in the Italian population is probably due to protective skin pigmentation.\n\n10066029|t|A future search based on mutation screening might establish a possible genotype phenotype correlation in Italian patients.\n10066029|a|A future search based on mutation screening might establish a possible genotype phenotype correlation in Italian patients.\n\n10196695|t|Angelman syndrome (AS) is a neurodevelopmental disorder caused by the absence of a maternal contribution to chromosome 15q11-q13.\n10196695|a|Angelman syndrome (AS) is a neurodevelopmental disorder caused by the absence of a maternal contribution to chromosome 15q11-q13.\n\n10196695|t|There are four classes of AS according to molecular or cytogenetic status: maternal microdeletion of 15q11-q13 (approximately 70% of AS patients); uniparental disomy (UPD); defects in a putative imprinting centre (IM); ...

# %%
output_df = read_and_merge_pubtator('output/biolarkgsc.PubTator')

# %%
output_df
# Out:
#     index                                          hpo_terms  \
# 0       0  brachydactyly (HP:0001156);aplastic or hypopla...
# 1       1  ear anomalies (HP:0000356);hearing loss (HP:00...
# 2       2  basal cell carcinoma (HP:0002671);carcinoma (H...
# 3       3  neurodevelopmental disorder (HP:0012759);neuro...
# 4       4  neurobehavioral disorders (HP:0000708);neurobe...
# ..    ...                                                ...
# 211   222  acoustic neuromas (HP:0009588);neuromas (HP:00...
# 212   223  overgrowth (HP:0001548);overgrowth (HP:0001548...
# 213   224  unilateral vestibular schwannomas (HP:0009590)...
# 214   225  basal cell carcinoma (HP:0002671);carcinoma (H...
# 215   227  preauricular pits (HP:0004467);deafness (HP:00...
#
#                                                hpo_ids
# 0    HP:0001156,HP:0008386,HP:0001792,HP:0100266,HP...
# 1    HP:0000356,HP:0000365,HP:0100258,HP:0001177,HP...
# 2    HP:0002671,HP:0030731,HP:0010603,HP:0010612,HP...
# 3                                           HP:0012759
# 4                                           HP:0000708
# ..                                                 ...
# 211  HP:0009588,HP:0030430,HP:0100008,HP:0002664,HP...
# 212                   HP:0001548,HP:0002591,HP:0001513
# 213  HP:0009590,HP:0009588,HP:0100008,HP:0001067,HP...
# 214  HP:0002671,HP:0030731,HP:0002664,HP:0009824,HP...
# 215  HP:0004467,HP:0000365,HP:0002009,HP:0000104,HP...
#
# [216 rows x 3 columns]

# %%
output_df.to_excel('../PhenoBERT/reference/20250818_biolarkgsc_splited_phenotagger.xlsx',index=False)

# %%
output_df.head(1)
# Out:
#   index                                          hpo_terms  \
# 0     0  brachydactyly (HP:0001156);aplastic or hypopla...
#
#                                              hpo_ids
# 0  HP:0001156,HP:0008386,HP:0001792,HP:0100266,HP...

# %%
output_df.hpo_terms[0]
# Out:
# 'brachydactyly (HP:0001156);aplastic or hypoplastic nails (HP:0008386);hypoplastic nails (HP:0001792);carpal and tarsal bones (HP:0100266);tarsal bones (HP:0041247);craniosynostosis (HP:0001363);dysplastic hip (HP:0001385);brachydactyly (HP:0001156);aplastic or hypoplastic nails (HP:0008386);hypoplastic nails (HP:0001792);carpal and tarsal bones (HP:0100266);tarsal bones (HP:0041247);craniosynostosis (HP:0001363);dysplastic hip (HP:0001385)'

# %%
df_hpo_mapping = pd.read_csv('../PhenoBERT/reference/2025-08-01_orphanet_WGS_database(HPO_ID_Mapping_v20250506).csv', sep=',')

# %%
hpo_mapping_dict = {}
for idx in df_hpo_mapping.index:
    hpo_mapping_dict[df_hpo_mapping.input_hpo_id[idx]] = df_hpo_mapping.mapped_main_id[idx]

# %%
biolarkgsc_copd_phenochf = pd.read_excel('../PhenoBERT/reference/biolarkgsc_copd_phenochf.xlsx',engine='openpyxl')

# %%
def hpo_map(hpo_id_list_str):
    if hpo_id_list_str =='-':
        return '-'
    hpo_id_list = hpo_id_list_str.split(',')
    normalized_hpo_id_list = []
    for hpo_id in hpo_id_list:
        if hpo_id not in normalized_hpo_id_list:
            normalized_hpo_id_list.append(hpo_mapping_dict.get(hpo_id,'-'))
    return ','.join(normalized_hpo_id_list)

def accuracy_calculator(true_hpo_str, pred_hpo_str):
    true_hpo_list = true_hpo_str.split(',')
    pred_hpo_list = pred_hpo_str.split(',')
    mapped_hpo_list = [hpo for hpo in pred_hpo_list if hpo in true_hpo_list]
    return len(mapped_hpo_list)/len(true_hpo_list)

# %%
biolarkgsc_copd_phenochf['normalized_hpo_ids'] = biolarkgsc_copd_phenochf['hpo_ids'].apply(hpo_map)

# %%
biolarkgsc_copd_phenochf[biolarkgsc_copd_phenochf['normalized_hpo_ids'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, clinical_summary, labels, hpo_ids, dataset, index, normalized_hpo_ids]
# Index: []

# %%
# output_df.head()
output_df['pheno_tagger_terms'] = output_df['hpo_terms']
output_df['pheno_tagger_hpo_ids'] = output_df['hpo_ids'].fillna('-')
output_df['index'] = output_df['index'].apply(lambda x:int(x))
# biolarkgsc_tagger.id = biolarkgsc_tagger.id.astype(str)
biolarkgsc_tagger = biolarkgsc_copd_phenochf.merge(output_df[['index','pheno_tagger_hpo_ids']], on='index', how='right')

# %%
biolarkgsc_tagger
# Out:
#            id                                   clinical_summary  \
# 0     1003450  A syndrome of brachydactyly (absence of some m...
# 1    10051003  Townes-Brocks syndrome (TBS) is an autosomal d...
# 2    10066029  Nevoid basal cell carcinoma syndrome (NBCCS) i...
# 3    10196695  Angelman syndrome (AS) is a neurodevelopmental...
# 4    10417280  Prader-Willi syndrome (PWS) and Angelman syndr...
# ..        ...                                                ...
# 211   9811917  Stereotactic radiosurgery is the principal alt...
# 212   9831341  We had previously described a patient with an ...
# 213   9863591  Patients who present with unilateral vestibula...
# 214   9931336  Mutations of the human Patched gene ( PTCH ) h...
# 215    998578  A woman with the autosomal dominant syndrome o...
#
#                                                 labels  \
# 0    HP_0001156;HP_0009881;HP_0001798;HP_0001792;HP...
# 1    HP_0000006;HP_0000006;HP_0000006;HP_0003828;HP...
# 2    HP_0002671;HP_0000006;HP_0000006;HP_0000006;HP...
# 3                                HP_0000707;HP_0001466
# 4                                HP_0000708;HP_0003745
# ..                                                 ...
# 211  HP_0009588;HP_0009588;HP_0100008;HP_0002664;HP...
# 212        HP_0001548;HP_0002591;HP_0001513;HP_0001548
# 213  HP_0009590;HP_0009588;HP_0100008;HP_0003593;HP...
# 214  HP_0002671;HP_0003745;HP_0002671;HP_0002885;HP...
# 215  HP_0000006;HP_0000006;HP_0004467;HP_0004467;HP...
#
#                                                hpo_ids     dataset  index  \
# 0    HP:0001156,HP:0009881,HP:0001798,HP:0001792,HP...  biolarkgsc      0
# 1    HP:0000006,HP:0000006,HP:0000006,HP:0003828,HP...  biolarkgsc      1
# 2    HP:0002671,HP:0000006,HP:0000006,HP:0000006,HP...  biolarkgsc      2
# 3                                HP:0000707,HP:0001466  biolarkgsc      3
# 4                                HP:0000708,HP:0003745  biolarkgsc      4
# ..                                                 ...         ...    ...
# 211  HP:0009588,HP:0009588,HP:0100008,HP:0002664,HP...  biolarkgsc    222
# 212        HP:0001548,HP:0002591,HP:0001513,HP:0001548  biolarkgsc    223
# 213  HP:0009590,HP:0009588,HP:0100008,HP:0003593,HP...  biolarkgsc    224
# 214  HP:0002671,HP:0003745,HP:0002671,HP:0002885,HP...  biolarkgsc    225
# 215  HP:0000006,HP:0000006,HP:0004467,HP:0004467,HP...  biolarkgsc    227
#
#                                     normalized_hpo_ids  \
# 0    HP:0001156,HP:0009881,HP:0001798,HP:0001792,HP...
# 1    HP:0000006,HP:0003828,HP:0003812,HP:0000356,HP...
# 2    HP:0002671,HP:0000006,HP:0003828,HP:0003812,HP...
# 3                                HP:0000707,HP:0001466
# 4                                HP:0000708,HP:0003745
# ..                                                 ...
# 211        HP:0009588,HP:0100008,HP:0002664,HP:0000707
# 212                   HP:0001548,HP:0002591,HP:0001513
# 213  HP:0009590,HP:0009588,HP:0100008,HP:0003593,HP...
# 214        HP:0002671,HP:0003745,HP:0002885,HP:0002664
# 215  HP:0000006,HP:0004467,HP:0009795,HP:0000365,HP...
#
#                                   pheno_tagger_hpo_ids
# 0    HP:0001156,HP:0008386,HP:0001792,HP:0100266,HP...
# 1    HP:0000356,HP:0000365,HP:0100258,HP:0001177,HP...
# 2    HP:0002671,HP:0030731,HP:0010603,HP:0010612,HP...
# 3                                           HP:0012759
# 4                                           HP:0000708
# ..                                                 ...
# 211  HP:0009588,HP:0030430,HP:0100008,HP:0002664,HP...
# 212                   HP:0001548,HP:0002591,HP:0001513
# 213  HP:0009590,HP:0009588,HP:0100008,HP:0001067,HP...
# 214  HP:0002671,HP:0030731,HP:0002664,HP:0009824,HP...
# 215  HP:0004467,HP:0000365,HP:0002009,HP:0000104,HP...
#
# [216 rows x 8 columns]

# %%
print(type(biolarkgsc_copd_phenochf.id[0]))
print(type(output_df.id[0]))
# Out:
# <class 'int'>
# <class 'str'>

# %%
biolarkgsc_tagger['normalized_pheno_tagger_hpo_ids'] = biolarkgsc_tagger['pheno_tagger_hpo_ids'].apply(hpo_map)

# %%
biolarkgsc_tagger['pheno_tagger_accuracy'] = biolarkgsc_tagger.apply(lambda x:accuracy_calculator(x.normalized_hpo_ids, x.normalized_pheno_tagger_hpo_ids), axis=1)

# %%
biolarkgsc_tagger['pheno_tagger_accuracy'].mean()
# Out:
# 0.5954651972414159
